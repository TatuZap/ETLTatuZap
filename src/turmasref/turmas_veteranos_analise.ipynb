# %%
from requests import get
import pandas as pd
TURMAS_SALAS_HORARIOS = "https://prograd.ufabc.edu.br/pdf/ajuste_2022_3_turmas.xlsx"
turmas_e_salas = get(TURMAS_SALAS_HORARIOS).content

# %%
with open("TURMAS_SALAS.xlsx","wb") as turmas:
    turmas.write(turmas_e_salas)

# %%
df = pd.read_excel(turmas_e_salas,sheet_name="AJUSTE_2022.3")

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4',
#        'Unnamed: 5', 'Unnamed: 6', 'Unnamed: 7', 'Unnamed: 8', 'Unnamed: 9',
#        'Unnamed: 10', 'Unnamed: 11', 'Unnamed: 12', 'Unnamed: 13',
#        'Unnamed: 14', 'Unnamed: 15', 'Unnamed: 16', 'Unnamed: 17',
#        'Unnamed: 18', 'Unnamed: 19', 'Unnamed: 20', 'Unnamed: 21',
#        'Unnamed: 22', 'Unnamed: 23', 'Unnamed: 24'],
#       dtype='object')

# %%
#display(df)
# Out:
#                                 Unnamed: 0       Unnamed: 1    Unnamed: 2  \
# 0                                    CURSO  CÓDIGO DE TURMA  Tipo de aula
# 1                  ENGENHARIA AEROESPACIAL  DA1ESZS019-17SB    PRESENCIAL
# 2                  ENGENHARIA AEROESPACIAL  DA1ESTS012-17SB    PRESENCIAL
# 3                BACHARELADO EM MATEMÁTICA  DA1MCTB001-17SA    PRESENCIAL
# 4                BACHARELADO EM MATEMÁTICA  DB1MCTB001-17SA    PRESENCIAL
# ...                                    ...              ...           ...
# 1055               ENGENHARIA AEROESPACIAL  DA1ESTS008-17SB    PRESENCIAL
# 1056               ENGENHARIA AEROESPACIAL  Na1ESTS008-17SB    PRESENCIAL
# 1057  BACHARELADO EM CIÊNCIA DA COMPUTAÇÃO  NA1MCZA030-17SA    PRESENCIAL
# 1058    BACHARELADO EM CIÊNCIAS BIOLÓGICAS  DA1NHT1064-15SA    PRESENCIAL
# 1059    BACHARELADO EM CIÊNCIAS BIOLÓGICAS  NA1NHT1064-15SA    PRESENCIAL
#
#                                              Unnamed: 3  \
# ...

# %%
df.columns = df.iloc[0]

# %%
df.drop(index=df.index[0], axis=0, inplace=True)

# %%
df.columns
# Out:
# Index(['CURSO', 'CÓDIGO DE TURMA', 'Tipo de aula', 'TURMA', 'Disciplina',
#        'Disciplina', 'turma', 'TEORIA', 'PRÁTICA', 'teoria COM SALA',
#        'prática  COM SALA', 'CAMPUS', 'TURNO', 'T-P-I', 'VAGAS TOTAIS',
#        'VAGAS INGRESSANTES', 'VAGAS PARA VETERANOS',
#        'TURMAS ALTA DEMANDA (não é possível soltar durante o ajuste)',
#        'VAGAS TOTAIS', 'VAGAS RESERVADAS SISU',
#        'VAGAS\nREMANESCENTES\n(PODEM OSCILAR DURANTE O AJUSTE)',
#        'DOCENTE TEORIA 1', 'DOCENTE TEORIA 2', 'DOCENTE PRÁTICA 1',
#        'DOCENTE PRÁTICA 2'],
#       dtype='object', name=0)

# %%
display(df["TEORIA"])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/.local/lib/python3.10/site-packages/pandas/core/indexes/base.py:3803, in Index.get_loc(self, key, method, tolerance)
#    3802 try:
# -> 3803     return self._engine.get_loc(casted_key)
#    3804 except KeyError as err:
#
# File ~/.local/lib/python3.10/site-packages/pandas/_libs/index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~/.local/lib/python3.10/site-packages/pandas/_libs/index.pyx:162, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~/.local/lib/python3.10/site-packages/pandas/_libs/index.pyx:203, in pandas._libs.index.IndexEngine._get_loc_duplicates()
#
# File ~/.local/lib/python3.10/site-packages/pandas/_libs/index.pyx:211, in pandas._libs.index.IndexEngine._maybe_get_bool_indexer()
#
# ...

# %%
from openpyxl import load_workbook
import pandas as pd

wb = load_workbook('TURMAS_SALAS.xlsx')
ws = wb['AJUSTE_2022.3']

# data = ws.values
# # Get the first line in file as a header line
# columns = next(data)[0:]
# # Create a DataFrame based on the second and subsequent lines of data
# df = pd.DataFrame(data, columns=columns)

# %%
display(ws)
# Out:
# <Worksheet "AJUSTE_2022.3">

# %%
data = ws.values
# Get the first line in file as a header line
columns = next(data)[0:]
# Create a DataFrame based on the second and subsequent lines of data
df = pd.DataFrame(data, columns=columns)

# %%
display(df)
# Out:
#                                 None                            None  \
# 0                              CURSO                 CÓDIGO DE TURMA
# 1        =' turmas sistema atual'!A2     =' turmas sistema atual'!B2
# 2        =' turmas sistema atual'!A3     =' turmas sistema atual'!B3
# 3        =' turmas sistema atual'!A4     =' turmas sistema atual'!B4
# 4        =' turmas sistema atual'!A5     =' turmas sistema atual'!B5
# ...                              ...                             ...
# 1055  =' turmas sistema atual'!A1056  =' turmas sistema atual'!B1056
# 1056  =' turmas sistema atual'!A1057  =' turmas sistema atual'!B1057
# 1057  =' turmas sistema atual'!A1058  =' turmas sistema atual'!B1058
# 1058  =' turmas sistema atual'!A1059  =' turmas sistema atual'!B1059
# 1059  =' turmas sistema atual'!A1060  =' turmas sistema atual'!B1060
#
#               None                            None  \
# 0     Tipo de aula                           TURMA
# ...
